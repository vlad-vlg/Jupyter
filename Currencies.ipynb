# %%
import requests
import xmltodict

url = 'http://www.cbr.ru/scripts/XML_daily.asp'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="windows-1251"?><ValCurs Date="22.09.2023" name="Foreign Currency Market"><Valute ID="R01010"><NumCode>036</NumCode><CharCode>AUD</CharCode><Nominal>1</Nominal><Name>\xc0\xe2\xf1\xf2\xf0\xe0\xeb\xe8\xe9\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>61,5176</Value></Valute><Valute ID="R01020A"><NumCode>944</NumCode><CharCode>AZN</CharCode><Nominal>1</Nominal><Name>\xc0\xe7\xe5\xf0\xe1\xe0\xe9\xe4\xe6\xe0\xed\xf1\xea\xe8\xe9 \xec\xe0\xed\xe0\xf2</Name><Value>56,5154</Value></Valute><Valute ID="R01035"><NumCode>826</NumCode><CharCode>GBP</CharCode><Nominal>1</Nominal><Name>\xd4\xf3\xed\xf2 \xf1\xf2\xe5\xf0\xeb\xe8\xed\xe3\xee\xe2 \xd1\xee\xe5\xe4\xe8\xed\xe5\xed\xed\xee\xe3\xee \xea\xee\xf0\xee\xeb\xe5\xe2\xf1\xf2\xe2\xe0</Name><Value>119,1153</Value></Valute><Valute ID="R01060"><NumCode>051</NumCode><CharCode>AMD</CharCode><Nominal>100</Nominal><Name>\xc0\xf0\xec\xff\xed\xf1\xea\xe8\xf5 \xe4\xf0\xe0\xec\xee\xe2</Name><Value>24,8677</Value></Valute><Valute ID="R01090B"><NumCode>933</NumCode><CharCode>BYN</CharCode><Nominal>1</Nominal><Name>\xc1\xe5\xeb\xee\xf0\xf3\xf1\xf1\xea\xe8\xe9 \xf0\xf3\xe1\xeb\xfc</Name><Value>29,4803</Value></Valute><Valute ID="R01100"><NumCode>975</NumCode><CharCode>BGN</CharCode><Nominal>1</Nominal><Name>\xc1\xee\xeb\xe3\xe0\xf0\xf1\xea\xe8\xe9 \xeb\xe5\xe2</Name><Value>52,5725</Value></Valute><Valute ID="R01115"><NumCode>986</NumCode><CharCode>BRL</CharCode><Nominal>1</Nominal><Name>\xc1\xf0\xe0\xe7\xe8\xeb\xfc\xf1\xea\xe8\xe9 \xf0\xe5\xe0\xeb</Name><Value>19,8161</Value></Valute><Valute ID="R01135"><NumCode>348</NumCode><CharCode>HUF</CharCode><Nominal>100</Nominal><Name>\xc2\xe5\xed\xe3\xe5\xf0\xf1\xea\xe8\xf5 \xf4\xee\xf0\xe8\xed\xf2\xee\xe2</Name><Value>26,5499</Value></Valute><Valute ID="R01150"><NumCode>704</NumCode><CharCode>VND</CharCode><Nominal>10000</Nominal><Name>\xc2\xfc\xe5\xf2\xed\xe0\xec\xf1\xea\xe8\xf5 \xe4\xee\xed\xe3\xee\xe2</Name><Value>39,9269</Value></Valute><Valute ID="R01200"><NumCode>344</NumCode><CharCode>HKD</CharCode><Nominal>1</Nominal><Name>\xc3\xee\xed\xea\xee\xed\xe3\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>12,3048</Value></Valute><Valute ID="R01210"><NumCode>981</NumCode><CharCode>GEL</CharCode><Nominal>1</Nominal><Name>\xc3\xf0\xf3\xe7\xe8\xed\xf1\xea\xe8\xe9 \xeb\xe0\xf0\xe8</Name><Value>35,9163</Value></Valute><Valute ID="R01215"><NumCode>208</NumCode><CharCode>DKK</CharCode><Nominal>1</Nominal><Name>\xc4\xe0\xf2\xf1\xea\xe0\xff \xea\xf0\xee\xed\xe0</Name><Value>13,7963</Value></Valute><Valute ID="R01230"><NumCode>784</NumCode><CharCode>AED</CharCode><Nominal>1</Nominal><Name>\xc4\xe8\xf0\xf5\xe0\xec \xce\xc0\xdd</Name><Value>26,1581</Value></Valute><Valute ID="R01235"><NumCode>840</NumCode><CharCode>USD</CharCode><Nominal>1</Nominal><Name>\xc4\xee\xeb\xeb\xe0\xf0 \xd1\xd8\xc0</Name><Value>96,0762</Value></Valute><Valute ID="R01239"><NumCode>978</NumCode><CharCode>EUR</CharCode><Nominal>1</Nominal><Name>\xc5\xe2\xf0\xee</Name><Value>102,3606</Value></Valute><Valute ID="R01240"><NumCode>818</NumCode><CharCode>EGP</CharCode><Nominal>10</Nominal><Name>\xc5\xe3\xe8\xef\xe5\xf2\xf1\xea\xe8\xf5 \xf4\xf3\xed\xf2\xee\xe2</Name><Value>31,0991</Value></Valute><Valute ID="R01270"><NumCode>356</NumCode><CharCode>INR</CharCode><Nominal>10</Nominal><Name>\xc8\xed\xe4\xe8\xe9\xf1\xea\xe8\xf5 \xf0\xf3\xef\xe8\xe9</Name><Value>11,5788</Value></Valute><Valute ID="R01280"><NumCode>360</NumCode><CharCode>IDR</CharCode><Nominal>10000</Nominal><Name>\xc8\xed\xe4\xee\xed\xe5\xe7\xe8\xe9\xf1\xea\xe8\xf5 \xf0\xf3\xef\xe8\xe9</Name><Value>62,4034</Value></Valute><Valute ID="R01335"><NumCode>398</NumCode><CharCode>KZT</CharCode><Nominal>100</Nominal><Name>\xca\xe0\xe7\xe0\xf5\xf1\xf2\xe0\xed\xf1\xea\xe8\xf5 \xf2\xe5\xed\xe3\xe5</Name><Value>20,3026</Value></Valute><Valute ID="R01350"><NumCode>124</NumCode><CharCode>CAD</CharCode><Nominal>1</Nominal><Name>\xca\xe0\xed\xe0\xe4\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>71,5758</Value ...

# %%
data = xmltodict.parse(response.content)
data
# Out:
# {'ValCurs': {'@Date': '22.09.2023',
#   '@name': 'Foreign Currency Market',
#   'Valute': [{'@ID': 'R01010',
#     'NumCode': '036',
#     'CharCode': 'AUD',
#     'Nominal': '1',
#     'Name': 'Австралийский доллар',
#     'Value': '61,5176'},
#    {'@ID': 'R01020A',
#     'NumCode': '944',
#     'CharCode': 'AZN',
#     'Nominal': '1',
#     'Name': 'Азербайджанский манат',
#     'Value': '56,5154'},
#    {'@ID': 'R01035',
#     'NumCode': '826',
#     'CharCode': 'GBP',
#     'Nominal': '1',
#     'Name': 'Фунт стерлингов Соединенного королевства',
#     'Value': '119,1153'},
#    {'@ID': 'R01060',
#     'NumCode': '051',
#     'CharCode': 'AMD',
#     'Nominal': '100',
#     'Name': 'Армянских драмов',
#     'Value': '24,8677'},
#    {'@ID': 'R01090B',
#     'NumCode': '933',
#     'CharCode': 'BYN',
#     'Nominal': '1',
#     'Name': 'Белорусский рубль',
#     'Value': '29,4803'},
#    {'@ID': 'R01100',
#     'NumCode': '975',
#     'CharCode': 'BGN',
#     'Nominal': '1',
#     'Name': 'Болгарский лев',
#     'Value': '52,5725'},
#    {'@ID': 'R01115',
#     'NumCode': '986',
#     'CharCode': 'BRL',
#     'Nominal': '1',
#     'Name': 'Бразильский реал',
#     'Value': '19,8161'},
#    {'@ID': 'R01135',
#     'NumCode': '348',
#     'CharCode': 'HUF',
#     'Nominal': '100',
#     'Name': 'Венгерских форинтов',
#     'Value': '26,5499'},
#    {'@ID': 'R01150',
#     'NumCode': '704',
#     'CharCode': 'VND',
#     'Nominal': '10000',
#     'Name': 'Вьетнамских донгов',
#     'Value': '39,9269'},
#    {'@ID': 'R01200',
#     'NumCode': '344',
#     'CharCode': 'HKD',
#     'Nominal': '1',
#     'Name': 'Гонконгский доллар',
#     'Value': '12,3048'},
#    {'@ID': 'R01210',
#     'NumCode': '981',
#     'CharCode': 'GEL',
#     'Nominal': '1',
#     'Name': 'Грузинский лари',
#     'Value': '35,9163'},
#    {'@ID': 'R01215',
#     'NumCode': '208',
#     'CharCode': 'DKK',
#     'Nominal': '1',
#     'Name': 'Датская крона',
#     'Value': '13,7963'},
#    {'@ID': 'R01230',
#     'NumCode': '784',
#     'CharCode': 'AED',
#     'Nominal': '1',
#     'Name': 'Дирхам ОАЭ',
#     'Value': '26,1581'},
#    {'@ID': 'R01235',
#     'NumCode': '840',
#     'CharCode': 'USD',
#     'Nominal': '1',
#     'Name': 'Доллар США',
#     'Value': '96,0762'},
#    {'@ID': 'R01239',
#     'NumCode': '978',
#     'CharCode': 'EUR',
#     'Nominal': '1',
#     'Name': 'Евро',
#     'Value': '102,3606'},
#    {'@ID': 'R01240',
#     'NumCode': '818',
#     'CharCode': 'EGP',
#     'Nominal': '10',
#     'Name': 'Египетских фунтов',
#     'Value': '31,0991'},
#    {'@ID': 'R01270',
#     'NumCode': '356',
#     'CharCode': 'INR',
#     'Nominal': '10',
#     'Name': 'Индийских рупий',
#     'Value': '11,5788'},
#    {'@ID': 'R01280',
#     'NumCode': '360',
#     'CharCode': 'IDR',
#     'Nominal': '10000',
#     'Name': 'Индонезийских рупий',
#     'Value': '62,4034'},
#    {'@ID': 'R01335',
#     'NumCode': '398',
#     'CharCode': 'KZT',
#     'Nominal': '100',
#     'Name': 'Казахстанских тенге',
#     'Value': '20,3026'},
#    {'@ID': 'R01350',
#     'NumCode': '124',
#     'CharCode': 'CAD',
#     'Nominal': '1',
#     'Name': 'Канадский доллар',
#     'Value': '71,5758'},
#    {'@ID': 'R01355',
#     'NumCode': '634',
#     'CharCode': 'QAR',
#     'Nominal': '1',
#     'Name': 'Катарский риал',
#     'Value': '26,3946'},
#    {'@ID': 'R01370',
#     'NumCode': '417',
#     'CharCode': 'KGS',
#     'Nominal': '10',
#     'Name': 'Киргизских сомов',
#     'Value': '10,8304'},
#    {'@ID': 'R01375',
#     'NumCode': '156',
#     'CharCode': 'CNY',
#     'Nominal': '1',
#     'Name': 'Китайский юань',
#     'Value': '13,1335'},
#    {'@ID': 'R01500',
#     'NumCode': '498',
#     'CharCode': 'MDL',
#     'Nominal': '10',
#     'Name': 'Молдавских леев',
#     'Value': '53,2432'},
#    {'@ID': 'R01530',
#     'NumCode': '554',
#     'CharCode': 'NZD',
#     'Nominal': '1',
#     'Name': 'Новозеландский доллар',
#     'Value': '56,8483'},
#    {'@ID': 'R01535',
#     'NumCode': '578',
#     'CharCode': 'NOK',
#     'Nominal': '10',
#     'Name': 'Норвежских крон',
#     'Value': '88,6418'},
#    {'@ID': 'R01565',
#     'NumCode': '985',
#     'CharCode': 'PLN',
#     'Nominal': '1',
#     'Name': 'Польский злотый',
#     'Value': '22,0824'},
#    {'@ID': 'R01585F',
#     'NumCode': '946',
#     'CharCode': 'RON',
#     'Nominal': '1',
#     'Name': 'Румынский лей',
#     'Value': '20,6004'},
#    {'@ID': 'R01589',
#     'NumCode': '960',
#     'CharCode': 'XDR',
#     'Nominal': '1',
#     'Name': 'СДР (специальные права заимствования)',
#     'Value': '126,7870'},
#    {'@ID': 'R01625',
#     'NumCode': '702',
#     'CharCode': 'SGD',
#     'Nominal': '1',
#     'Name': 'Сингапурский доллар',
#     'Value': '70,2620'},
#    {'@ID': 'R01670',
#     'NumCode': '972',
#     'CharCode': 'TJS',
#     'Nominal': '10',
#     'Name': 'Таджикских сомони',
#     'Value': '87,6520'},
#    {'@ID': 'R01675',
#     'NumCode': '764',
#     'CharCode': 'THB',
#     'Nominal': '10',
#     'Name': 'Таиландских батов',
#     'Value': '26,5553'},
#    {'@ID': 'R01700J',
#     'NumCode': '949',
#     'CharCode': 'TRY',
#     'Nominal': '10',
#     'Name': 'Турецких лир',
#     'Value': '35,5636'},
#    {'@ID': 'R01710A',
#     'NumCode': '934',
#     'CharCode': 'TMT',
#     'Nominal': '1',
#     'Name': 'Новый туркменский манат',
#     'Value': '27,4503'},
#    {'@ID': 'R01717',
#     'NumCode': '860',
#     'CharCode': 'UZS',
#     'Nominal': '10000',
#     'Name': 'Узбекских сумов',
#     'Value': '78,8926'},
#    {'@ID': 'R01720',
#     'NumCode': '980',
#     'CharCode': 'UAH',
#     'Nominal': '10',
#     'Name': 'Украинских гривен',
#     'Value': '26,0138'},
#    {'@ID': 'R01760',
#     'NumCode': '203',
#     'CharCode': 'CZK',
#     'Nominal': '10',
#     'Name': 'Чешских крон',
#     'Value': '42,1331'},
#    {'@ID': 'R01770',
#     'NumCode': '752',
#     'CharCode': 'SEK',
#     'Nominal': '10',
#     'Name': 'Шведских крон',
#     'Value': '86,0744'},
#    {'@ID': 'R01775',
#     'NumCode': '756',
#     'CharCode': 'CHF',
#     'Nominal': '1',
#     'Name': 'Швейцарский франк',
#     'Value': '105,9041'},
#    {'@ID': 'R01805F',
#     'NumCode': '941',
#     'CharCode': 'RSD',
#     'Nominal': '100',
#     'Name': 'Сербских динаров',
#     'Value': '87,2092'},
#    {'@ID': 'R01810',
#     'NumCode': '710',
#     'CharCode': 'ZAR',
#     'Nominal': '10',
#     'Name': 'Южноафриканских рэндов',
#     'Value': '51,0433'},
#    {'@ID': 'R01815',
#     'NumCode': '410',
#     'CharCode': 'KRW',
#     'Nominal': '1000',
#     'Name': 'Вон Республики Корея',
#     'Value': '71,7147'},
#    {'@ID': 'R01820',
#     'NumCode': '392',
#     'CharCode': 'JPY',
#     'Nominal': '100',
#     'Name': 'Японских иен',
#     'Value': '64,7676'}]}}

# %%
items = []
for item in data['ValCurs']['Valute']:
    items.append(item)
items
# Out:
# [{'@ID': 'R01010',
#   'NumCode': '036',
#   'CharCode': 'AUD',
#   'Nominal': '1',
#   'Name': 'Австралийский доллар',
#   'Value': '61,5176'},
#  {'@ID': 'R01020A',
#   'NumCode': '944',
#   'CharCode': 'AZN',
#   'Nominal': '1',
#   'Name': 'Азербайджанский манат',
#   'Value': '56,5154'},
#  {'@ID': 'R01035',
#   'NumCode': '826',
#   'CharCode': 'GBP',
#   'Nominal': '1',
#   'Name': 'Фунт стерлингов Соединенного королевства',
#   'Value': '119,1153'},
#  {'@ID': 'R01060',
#   'NumCode': '051',
#   'CharCode': 'AMD',
#   'Nominal': '100',
#   'Name': 'Армянских драмов',
#   'Value': '24,8677'},
#  {'@ID': 'R01090B',
#   'NumCode': '933',
#   'CharCode': 'BYN',
#   'Nominal': '1',
#   'Name': 'Белорусский рубль',
#   'Value': '29,4803'},
#  {'@ID': 'R01100',
#   'NumCode': '975',
#   'CharCode': 'BGN',
#   'Nominal': '1',
#   'Name': 'Болгарский лев',
#   'Value': '52,5725'},
#  {'@ID': 'R01115',
#   'NumCode': '986',
#   'CharCode': 'BRL',
#   'Nominal': '1',
#   'Name': 'Бразильский реал',
#   'Value': '19,8161'},
#  {'@ID': 'R01135',
#   'NumCode': '348',
#   'CharCode': 'HUF',
#   'Nominal': '100',
#   'Name': 'Венгерских форинтов',
#   'Value': '26,5499'},
#  {'@ID': 'R01150',
#   'NumCode': '704',
#   'CharCode': 'VND',
#   'Nominal': '10000',
#   'Name': 'Вьетнамских донгов',
#   'Value': '39,9269'},
#  {'@ID': 'R01200',
#   'NumCode': '344',
#   'CharCode': 'HKD',
#   'Nominal': '1',
#   'Name': 'Гонконгский доллар',
#   'Value': '12,3048'},
#  {'@ID': 'R01210',
#   'NumCode': '981',
#   'CharCode': 'GEL',
#   'Nominal': '1',
#   'Name': 'Грузинский лари',
#   'Value': '35,9163'},
#  {'@ID': 'R01215',
#   'NumCode': '208',
#   'CharCode': 'DKK',
#   'Nominal': '1',
#   'Name': 'Датская крона',
#   'Value': '13,7963'},
#  {'@ID': 'R01230',
#   'NumCode': '784',
#   'CharCode': 'AED',
#   'Nominal': '1',
#   'Name': 'Дирхам ОАЭ',
#   'Value': '26,1581'},
#  {'@ID': 'R01235',
#   'NumCode': '840',
#   'CharCode': 'USD',
#   'Nominal': '1',
#   'Name': 'Доллар США',
#   'Value': '96,0762'},
#  {'@ID': 'R01239',
#   'NumCode': '978',
#   'CharCode': 'EUR',
#   'Nominal': '1',
#   'Name': 'Евро',
#   'Value': '102,3606'},
#  {'@ID': 'R01240',
#   'NumCode': '818',
#   'CharCode': 'EGP',
#   'Nominal': '10',
#   'Name': 'Египетских фунтов',
#   'Value': '31,0991'},
#  {'@ID': 'R01270',
#   'NumCode': '356',
#   'CharCode': 'INR',
#   'Nominal': '10',
#   'Name': 'Индийских рупий',
#   'Value': '11,5788'},
#  {'@ID': 'R01280',
#   'NumCode': '360',
#   'CharCode': 'IDR',
#   'Nominal': '10000',
#   'Name': 'Индонезийских рупий',
#   'Value': '62,4034'},
#  {'@ID': 'R01335',
#   'NumCode': '398',
#   'CharCode': 'KZT',
#   'Nominal': '100',
#   'Name': 'Казахстанских тенге',
#   'Value': '20,3026'},
#  {'@ID': 'R01350',
#   'NumCode': '124',
#   'CharCode': 'CAD',
#   'Nominal': '1',
#   'Name': 'Канадский доллар',
#   'Value': '71,5758'},
#  {'@ID': 'R01355',
#   'NumCode': '634',
#   'CharCode': 'QAR',
#   'Nominal': '1',
#   'Name': 'Катарский риал',
#   'Value': '26,3946'},
#  {'@ID': 'R01370',
#   'NumCode': '417',
#   'CharCode': 'KGS',
#   'Nominal': '10',
#   'Name': 'Киргизских сомов',
#   'Value': '10,8304'},
#  {'@ID': 'R01375',
#   'NumCode': '156',
#   'CharCode': 'CNY',
#   'Nominal': '1',
#   'Name': 'Китайский юань',
#   'Value': '13,1335'},
#  {'@ID': 'R01500',
#   'NumCode': '498',
#   'CharCode': 'MDL',
#   'Nominal': '10',
#   'Name': 'Молдавских леев',
#   'Value': '53,2432'},
#  {'@ID': 'R01530',
#   'NumCode': '554',
#   'CharCode': 'NZD',
#   'Nominal': '1',
#   'Name': 'Новозеландский доллар',
#   'Value': '56,8483'},
#  {'@ID': 'R01535',
#   'NumCode': '578',
#   'CharCode': 'NOK',
#   'Nominal': '10',
#   'Name': 'Норвежских крон',
#   'Value': '88,6418'},
#  {'@ID': 'R01565',
#   'NumCode': '985',
#   'CharCode': 'PLN',
#   'Nominal': '1',
#   'Name': 'Польский злотый',
#   'Value': '22,0824'},
#  {'@ID': 'R01585F',
#   'NumCode': '946',
#   'CharCode': 'RON',
#   'Nominal': '1',
#   'Name': 'Румынский лей',
#   'Value': '20,6004'},
#  {'@ID': 'R01589',
#   'NumCode': '960',
#   'CharCode': 'XDR',
#   'Nominal': '1',
#   'Name': 'СДР (специальные права заимствования)',
#   'Value': '126,7870'},
#  {'@ID': 'R01625',
#   'NumCode': '702',
#   'CharCode': 'SGD',
#   'Nominal': '1',
#   'Name': 'Сингапурский доллар',
#   'Value': '70,2620'},
#  {'@ID': 'R01670',
#   'NumCode': '972',
#   'CharCode': 'TJS',
#   'Nominal': '10',
#   'Name': 'Таджикских сомони',
#   'Value': '87,6520'},
#  {'@ID': 'R01675',
#   'NumCode': '764',
#   'CharCode': 'THB',
#   'Nominal': '10',
#   'Name': 'Таиландских батов',
#   'Value': '26,5553'},
#  {'@ID': 'R01700J',
#   'NumCode': '949',
#   'CharCode': 'TRY',
#   'Nominal': '10',
#   'Name': 'Турецких лир',
#   'Value': '35,5636'},
#  {'@ID': 'R01710A',
#   'NumCode': '934',
#   'CharCode': 'TMT',
#   'Nominal': '1',
#   'Name': 'Новый туркменский манат',
#   'Value': '27,4503'},
#  {'@ID': 'R01717',
#   'NumCode': '860',
#   'CharCode': 'UZS',
#   'Nominal': '10000',
#   'Name': 'Узбекских сумов',
#   'Value': '78,8926'},
#  {'@ID': 'R01720',
#   'NumCode': '980',
#   'CharCode': 'UAH',
#   'Nominal': '10',
#   'Name': 'Украинских гривен',
#   'Value': '26,0138'},
#  {'@ID': 'R01760',
#   'NumCode': '203',
#   'CharCode': 'CZK',
#   'Nominal': '10',
#   'Name': 'Чешских крон',
#   'Value': '42,1331'},
#  {'@ID': 'R01770',
#   'NumCode': '752',
#   'CharCode': 'SEK',
#   'Nominal': '10',
#   'Name': 'Шведских крон',
#   'Value': '86,0744'},
#  {'@ID': 'R01775',
#   'NumCode': '756',
#   'CharCode': 'CHF',
#   'Nominal': '1',
#   'Name': 'Швейцарский франк',
#   'Value': '105,9041'},
#  {'@ID': 'R01805F',
#   'NumCode': '941',
#   'CharCode': 'RSD',
#   'Nominal': '100',
#   'Name': 'Сербских динаров',
#   'Value': '87,2092'},
#  {'@ID': 'R01810',
#   'NumCode': '710',
#   'CharCode': 'ZAR',
#   'Nominal': '10',
#   'Name': 'Южноафриканских рэндов',
#   'Value': '51,0433'},
#  {'@ID': 'R01815',
#   'NumCode': '410',
#   'CharCode': 'KRW',
#   'Nominal': '1000',
#   'Name': 'Вон Республики Корея',
#   'Value': '71,7147'},
#  {'@ID': 'R01820',
#   'NumCode': '392',
#   'CharCode': 'JPY',
#   'Nominal': '100',
#   'Name': 'Японских иен',
#   'Value': '64,7676'}]

# %%
my_array = []
for item in data['ValCurs']['Valute']:
    my_set = [item['CharCode'], item['Name'], item['Value']]
    my_array.append(my_set)
    print(my_set)
# Out:
# ['AUD', 'Австралийский доллар', '61,5176']
# ['AZN', 'Азербайджанский манат', '56,5154']
# ['GBP', 'Фунт стерлингов Соединенного королевства', '119,1153']
# ['AMD', 'Армянских драмов', '24,8677']
# ['BYN', 'Белорусский рубль', '29,4803']
# ['BGN', 'Болгарский лев', '52,5725']
# ['BRL', 'Бразильский реал', '19,8161']
# ['HUF', 'Венгерских форинтов', '26,5499']
# ['VND', 'Вьетнамских донгов', '39,9269']
# ['HKD', 'Гонконгский доллар', '12,3048']
# ['GEL', 'Грузинский лари', '35,9163']
# ['DKK', 'Датская крона', '13,7963']
# ['AED', 'Дирхам ОАЭ', '26,1581']
# ['USD', 'Доллар США', '96,0762']
# ['EUR', 'Евро', '102,3606']
# ['EGP', 'Египетских фунтов', '31,0991']
# ['INR', 'Индийских рупий', '11,5788']
# ['IDR', 'Индонезийских рупий', '62,4034']
# ['KZT', 'Казахстанских тенге', '20,3026']
# ['CAD', 'Канадский доллар', '71,5758']
# ['QAR', 'Катарский риал', '26,3946']
# ['KGS', 'Киргизских сомов', '10,8304']
# ['CNY', 'Китайский юань', '13,1335']
# ['MDL', 'Молдавских леев', '53,2432']
# ['NZD', 'Новозеландский доллар', '56,8483']
# ['NOK', 'Норвежских крон', '88,6418']
# ['PLN', 'Польский злотый', '22,0824']
# ['RON', 'Румынский лей', '20,6004']
# ['XDR', 'СДР (специальные права заимствования)', '126,7870']
# ['SGD', 'Сингапурский доллар', '70,2620']
# ['TJS', 'Таджикских сомони', '87,6520']
# ['THB', 'Таиландских батов', '26,5553']
# ['TRY', 'Турецких лир', '35,5636']
# ['TMT', 'Новый туркменский манат', '27,4503']
# ['UZS', 'Узбекских сумов', '78,8926']
# ['UAH', 'Украинских гривен', '26,0138']
# ['CZK', 'Чешских крон', '42,1331']
# ['SEK', 'Шведских крон', '86,0744']
# ['CHF', 'Швейцарский франк', '105,9041']
# ['RSD', 'Сербских динаров', '87,2092']
# ['ZAR', 'Южноафриканских рэндов', '51,0433']
# ['KRW', 'Вон Республики Корея', '71,7147']
# ['JPY', 'Японских иен', '64,7676']

# %%
my_array
# Out:
# [['AUD', 'Австралийский доллар', '61,5176'],
#  ['AZN', 'Азербайджанский манат', '56,5154'],
#  ['GBP', 'Фунт стерлингов Соединенного королевства', '119,1153'],
#  ['AMD', 'Армянских драмов', '24,8677'],
#  ['BYN', 'Белорусский рубль', '29,4803'],
#  ['BGN', 'Болгарский лев', '52,5725'],
#  ['BRL', 'Бразильский реал', '19,8161'],
#  ['HUF', 'Венгерских форинтов', '26,5499'],
#  ['VND', 'Вьетнамских донгов', '39,9269'],
#  ['HKD', 'Гонконгский доллар', '12,3048'],
#  ['GEL', 'Грузинский лари', '35,9163'],
#  ['DKK', 'Датская крона', '13,7963'],
#  ['AED', 'Дирхам ОАЭ', '26,1581'],
#  ['USD', 'Доллар США', '96,0762'],
#  ['EUR', 'Евро', '102,3606'],
#  ['EGP', 'Египетских фунтов', '31,0991'],
#  ['INR', 'Индийских рупий', '11,5788'],
#  ['IDR', 'Индонезийских рупий', '62,4034'],
#  ['KZT', 'Казахстанских тенге', '20,3026'],
#  ['CAD', 'Канадский доллар', '71,5758'],
#  ['QAR', 'Катарский риал', '26,3946'],
#  ['KGS', 'Киргизских сомов', '10,8304'],
#  ['CNY', 'Китайский юань', '13,1335'],
#  ['MDL', 'Молдавских леев', '53,2432'],
#  ['NZD', 'Новозеландский доллар', '56,8483'],
#  ['NOK', 'Норвежских крон', '88,6418'],
#  ['PLN', 'Польский злотый', '22,0824'],
#  ['RON', 'Румынский лей', '20,6004'],
#  ['XDR', 'СДР (специальные права заимствования)', '126,7870'],
#  ['SGD', 'Сингапурский доллар', '70,2620'],
#  ['TJS', 'Таджикских сомони', '87,6520'],
#  ['THB', 'Таиландских батов', '26,5553'],
#  ['TRY', 'Турецких лир', '35,5636'],
#  ['TMT', 'Новый туркменский манат', '27,4503'],
#  ['UZS', 'Узбекских сумов', '78,8926'],
#  ['UAH', 'Украинских гривен', '26,0138'],
#  ['CZK', 'Чешских крон', '42,1331'],
#  ['SEK', 'Шведских крон', '86,0744'],
#  ['CHF', 'Швейцарский франк', '105,9041'],
#  ['RSD', 'Сербских динаров', '87,2092'],
#  ['ZAR', 'Южноафриканских рэндов', '51,0433'],
#  ['KRW', 'Вон Республики Корея', '71,7147'],
#  ['JPY', 'Японских иен', '64,7676']]
